# %% [markdown]
# ## Problem: Two Sum II - Input Array Is Sorted
#
# Given a **1-indexed** array of integers `numbers` that is already **sorted in non-decreasing order**, find two numbers such that they add up to a specific `target` number. Let these two numbers be `numbers[index1]` and `numbers[index2]` where `1 <= index1 < index2 <= numbers.length`.
#
# Return the indices of the two numbers, `index1` and `index2`, **added by one** as an integer array `[index1, index2]` of length 2.
#
# The tests are generated such that there is **exactly one solution**. You may not use the same element twice.
#
# Your solution must use only constant extra space.
#
# ### Example 1:
# ```
# Input: numbers = [2,7,11,15], target = 9
# Output: [1,2]
# Explanation: The sum of 2 and 7 is 9. Therefore, index1 = 1, index2 = 2. We return [1, 2].
# ```
#
# ### Example 2:
# ```
# Input: numbers = [2,3,4], target = 6
# Output: [1,3]
# Explanation: The sum of 2 and 4 is 6. Therefore index1 = 1, index2 = 3. We return [1, 3].
# ```
#
# ### Example 3:
# ```
# Input: numbers = [-1,0], target = -1
# Output: [1,2]
# Explanation: The sum of -1 and 0 is -1. Therefore index1 = 1, index2 = 2. We return [1, 2].
# ```
#
# ### Constraints:
# - `2 <= numbers.length <= 3 * 10^4`
# - `-1000 <= numbers[i] <= 1000`
# - `numbers` is sorted in **non-decreasing order**.
# - `-1000 <= target <= 1000`
# - The tests are generated such that there is exactly one solution.

# %% [markdown]
# ## 1st Tr: Mine

# %%
def two_sum_II(numbers, target):
    seen = {}
    for i in range(len(numbers)):
        complement = target - numbers[i]
        if complement in seen:
            return [seen[complement], i + 1]
        seen[numbers[i]] = i + 1

# %%
# Input: numbers = [2,7,11,15], target = 9
# Output: [1,2]

numbers = [2, 7, 11, 15]
target = 9
two_sum_II(numbers, target)
# Out:
# [1, 2]

# %%
# Input: numbers = [2,3,4], target = 6
# Output: [1,3]

numbers = [2, 3, 4]
target = 6
two_sum_II(numbers, target)
# Out:
# [1, 3]

# %%
# Input: numbers = [-1,0], target = -1
# Output: [1,2]

numbers = [-1, 0]
target = -1
two_sum_II(numbers, target)
# Out:
# [1, 2]

# %% [markdown]
# ## Review: Two Sum II - Input Array Is Sorted
#
# ### ❌ Error: Violates space constraint
# - Using a dictionary `seen` takes **O(n) space**
# - Problem requires **O(1) extra space** (constant)
# - The array is **sorted** — use that property instead
#
# ### 💡 Hint:
# - Use **two pointers**: one at the start, one at the end
# - If `numbers[left] + numbers[right] > target` → move `right` left
# - If `numbers[left] + numbers[right] < target` → move `left` right
# - If equal → return `[left+1, right+1]`

# %% [markdown]
# ## 2nd Try: Two pointers

# %%
def two_sum_II_v2(numbers, target):
    left = 0
    right = len(numbers) - 1
    while (left < right):
        if (numbers[left] + numbers[right]) < target:
            left += 1
        elif (numbers[left] + numbers[right]) > target:
            right -= 1
        else:
            return [left+1, right+1]

# %%
# Input: numbers = [2,7,11,15], target = 9
# Output: [1,2]

numbers = [2, 7, 11, 15]
target = 9
two_sum_II_v2(numbers, target)
# Out:
# [1, 2]

# %%
# Input: numbers = [2,3,4], target = 6
# Output: [1,3]

numbers = [2, 3, 4]
target = 6
two_sum_II_v2(numbers, target)
# Out:
# [1, 3]

# %%
# Input: numbers = [-1,0], target = -1
# Output: [1,2]

numbers = [-1, 0]
target = -1
two_sum_II_v2(numbers, target)
# Out:
# [1, 2]

# %% [markdown]
# ## Review: Two Sum II v2
#
# ### ✅ Correct
# - Two pointers approach — O(n) time, O(1) space
# - Correctly handles all three cases (<, >, ==)
# - Returns 1-indexed indices
# - Proper loop condition `left < right`
#
# ### 🔧 Minor style improvements
# - Parentheses around conditions are unnecessary in Python:
#   `if numbers[left] + numbers[right] < target:` is cleaner
# - Function name could match the original: `two_sum` instead of `two_sum_II_v2`

# %%
def two_sum_II_v3(numbers, target):
    left = 0
    right = len(numbers) - 1
    while (left < right):
        if numbers[left] + numbers[right] < target:
            left += 1
        elif numbers[left] + numbers[right] > target:
            right -= 1
        else:
            return [left+1, right+1]
